# %%
# !pip install PyPDF2

import PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.6 MB/s eta 0:00:00
# ...

# %%
#1 - Create a Laptop class with a private attribute __price. Implement a method set_price(new_price)
  # to update the price and get_price() to retrieve the price.

class Laptop:
    def __init__(self, price=0):
      self.__price = price

    def set_price(self, new_price):
        if new_price >= 0:
            self.__price = new_price
        else:
            print("Invalid price! Must be non-negative.")

    def get_price(self):
        return self.__price

l1 = Laptop(50000)
print("Initial Price:", l1.get_price())

l1.set_price(55000)
print("Updated Price:", l1.get_price())

l1.set_price(-1000)
print("Final Price:", l1.get_price())
# Out:
# Initial Price: 50000
# Updated Price: 55000
# Invalid price! Must be non-negative.
# Final Price: 55000

# %%
#2 - Create a BankAccount class with a private attribute __balance. Implement methods to deposit,
# withdraw, and check balance while ensuring the balance cannot be modified directly.

class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ₹{amount}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if amount <= 0:
            print("Withdrawal amount must be positive.")
        elif amount > self.__balance:
            print("Insufficient balance.")
        else:
            self.__balance -= amount
            print(f"Withdrawn: ₹{amount}")

    def get_balance(self):
         return self.__balance

account = BankAccount(1000)
account.deposit(500)
account.withdraw(300)
print("Current Balance: ₹", account.get_balance())
# Out:
# Deposited: ₹500
# Withdrawn: ₹300
# Current Balance: ₹ 1200

# %%
#3 - Create a Movie class with a private attribute __rating.
# Implement methods to set and get the rating, ensuring the rating is between 1 and 10.

class Movie:
    def __init__(self, rating):
        self.__rating = 0
        self.set_rating(rating)

    def set_rating(self, rating):
        if 1 <= rating <= 10:
            self.__rating = rating
        else:
            print("Rating must be between 1 and 10.")

    def get_rating(self):
        return self.__rating

movie1 = Movie(8)

print("Current Rating:", movie1.get_rating())
# Out:
# Current Rating: 8

# %%
#4 - Create a Book class with private attributes __title and __author.
#Implement a constructor to set these values and provide methods to retrieve them.

class Book:
    def __init__(self, title, author):
        self.__title = title
        self.__author = author

    def get_title(self):
        return self.__title

    def get_author(self):
        return self.__author

book1 = Book("The Alchemist", "Paulo Coelho")

print("Title:", book1.get_title())
print("Author:", book1.get_author())
# Out:
# Title: The Alchemist
# Author: Paulo Coelho

# %%
#5 - Create a Car class with a private attribute __speed. Implement methods to increase speed,
# decrease speed, and get the current speed, ensuring speed does not go below 0.

class Car:
    def __init__(self, speed=0):
        self.__speed = speed # Use private attribute
        # Ensure initial speed is not negative
        if self.__speed < 0:
            self.__speed = 0

    def increase_speed(self, increment):
        self.__speed += increment

    def decrease_speed(self, decrement):
        self.__speed -= decrement
        if self.__speed < 0: # Ensure speed does not go below 0
            self.__speed = 0

    def get_speed(self):
        return self.__speed

# Example usage:
car1 = Car(50)
print("Initial speed:", car1.get_speed())

car1.increase_speed(30)
print("Speed after increasing:", car1.get_speed())

car1.decrease_speed(100)
print("Speed after decreasing by too much:", car1.get_speed())

car1.decrease_speed(10)
print("Speed after further decreasing:", car1.get_speed())
# Out:
# Initial speed: 50
# Speed after increasing: 80
# Speed after decreasing by too much: 0
# Speed after further decreasing: 0
